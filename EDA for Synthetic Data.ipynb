# %% [markdown]
# # Explanatory Analysis for Synthetic Dataset
# Github Repo: https://github.com/jc000222/SNP_project_codes

# %% [markdown]
# Intall and call the package

# %%
from snp.eda import EDARunner, MultiEDARunner
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the determinist dataset that has no noise.

# %%
df_deterministic = pd.read_csv('synthetic_data/Deterministic-Mean0std0p0.csv')
df_deterministic['Timestamp'] = pd.to_datetime(df_deterministic['Timestamp'])
EDA_deterministic = EDARunner(df_deterministic,"Deterministic | Mean=0 | Std=0")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  30000 non-null  datetime64[ns]
#  1   Values     30000 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 468.9 KB
# None
#                  Timestamp        Values
# count                30000  3.000000e+04
# mean   2021-09-16 23:30:00 -3.919827e-17
# min    2020-01-01 00:00:00 -1.000000e+00
# 25%    2020-11-08 11:45:00 -6.956525e-01
# 50%    2021-09-16 23:30:00 -7.350000e-16
# 75%    2022-07-26 11:15:00  6.956525e-01
# max    2023-06-03 23:00:00  1.000000e+00
# std                    NaN  7.071186e-01
#             Timestamp    Values
# 0 2020-01-01 00:00:00  0.000000
# 1 2020-01-01 01:00:00  0.062791
# 2 2020-01-01 02:00:00  0.125333
# 3 2020-01-01 03:00:00  0.187381
# 4 2020-01-01 04:00:00  0.248690
# Time Period: 1249 days 23:00:00
# Frequency: H

# %%
EDA_deterministic.overview(Zoom_in=(0,1000))

# %%
EDA_deterministic.plot_decomposition()

# %% [markdown]
# Read the dataset that holds frequency and phase constant, adding noise to amplitude.

# %%
df_amp_noise_single = pd.read_csv('synthetic_data/AmpNoise-Mean0-Std0p5326.csv')
df_amp_noise_single['Timestamp'] = pd.to_datetime(df_amp_noise_single['Timestamp'])
EDA_amp_noise_single = EDARunner(df_amp_noise_single,"AmpNoise | Mean=0 | Std=0.5",Show_info=False)
EDA_amp_noise_single.overview(Zoom_in=(0,1000))

# %%
EDA_deterministic.plot_decomposition()

# %% [markdown]
# Read the dataset that holds amplitude and phase constant, adding noise to frequency.

# %%
df_freq_noise_single = pd.read_csv('synthetic_data/FreqNoise-Mean0-Std0p19.csv')
df_freq_noise_single['Timestamp'] = pd.to_datetime(df_freq_noise_single['Timestamp'])
EDA_freq_noise_single = EDARunner(df_freq_noise_single,"FreqNoise | Mean=0 | Std=0.19",Show_info=False)
EDA_freq_noise_single.overview(Zoom_in=(0,1000))

# %%
EDA_freq_noise_single.plot_decomposition()

# %% [markdown]
# Read the dataset that holds amplitude and frequency constant, adding noise to phase.

# %%
df_phase_noise_single = pd.read_csv('synthetic_data/PhaseNoise-Mean0-Std0p6848.csv')
df_phase_noise_single['Timestamp'] = pd.to_datetime(df_phase_noise_single['Timestamp'])
EDA_phase_noise_single = EDARunner(df_phase_noise_single,"phaseNoise | Mean=0 | Std=0.68",Show_info=False)
EDA_phase_noise_single.overview(Zoom_in=(0,1000))

# %%
EDA_phase_noise_single.plot_decomposition()

# %% [markdown]
# Pure noise.

# %%
df_noise_single = pd.read_csv('synthetic_data/WhiteNoiseTimeSeries.csv')
df_noise_single['Timestamp'] = pd.to_datetime(df_noise_single['Timestamp'])
EDA_noise_single = EDARunner(df_noise_single,"Noise | Mean=0 | Std=0.5",Show_info=False)
EDA_noise_single.overview(Zoom_in=(0,1000))

# %%
EDA_noise_single.plot_decomposition()

# %% [markdown]
# Add different noise to the sine wave.

# %%
df_amp_noise = pd.read_csv('synthetic_data/AmpNoiseALL-Mean0-Std0to1p75.csv')
df_amp_noise['Timestamp'] = pd.to_datetime(df_amp_noise['Timestamp'])
EDA_amp_noise = MultiEDARunner(df_amp_noise, "Amplitude Noise",colormap=plt.cm.Blues)
# Out:
# Columns: Index(['Timestamp', 'Value 0p0', 'Value 0p0761', 'Value 0p1522',
#        'Value 0p2283', 'Value 0p3043', 'Value 0p3804', 'Value 0p4565',
#        'Value 0p5326', 'Value 0p6087', 'Value 0p6848', 'Value 0p7609',
#        'Value 0p837', 'Value 0p913', 'Value 0p9891', 'Value 1p0652',
#        'Value 1p1413', 'Value 1p2174', 'Value 1p2935', 'Value 1p3696',
#        'Value 1p4457', 'Value 1p5217', 'Value 1p5978', 'Value 1p6739'],
#       dtype='object')
#             Timestamp  Value 0p0  Value 0p0761  Value 0p1522  Value 0p2283  \
# 0 2020-01-01 00:00:00   0.000000     -0.037912      0.045881      0.208556
# 1 2020-01-01 01:00:00   0.062791      0.075417      0.223412     -0.199657
# 2 2020-01-01 02:00:00   0.125333      0.047030      0.159980     -0.534172
# 3 2020-01-01 03:00:00   0.187381      0.223453      0.421408      0.450444
# 4 2020-01-01 04:00:00   0.248690      0.252617      0.233532      0.407086
#
#    Value 0p3043  Value 0p3804  Value 0p4565  Value 0p5326  Value 0p6087  ...  \
# 0      0.385681      0.286594      0.112373      0.226448      1.829618  ...
# 1      0.664541     -0.052617     -0.390577      0.381247      0.445621  ...
# 2      0.039311      0.445685     -0.196458     -0.336208     -0.174662  ...
# 3      0.212820     -0.332879     -0.262715     -0.114205     -0.036666  ...
# 4      0.350919     -0.200164      0.067528      0.675706     -0.148997  ...
#
#    Value 0p9891  Value 1p0652  Value 1p1413  Value 1p2174  Value 1p2935  \
# 0      0.886459      0.957983      0.664187      0.946356      0.567857
# 1     -0.635013      0.287127      0.728452      0.207842     -1.292597
# 2     -0.524869      0.252776      2.861458     -1.654537     -0.290962
# 3      0.423393     -0.119279     -0.271218     -1.082179      0.237891
# 4      1.742280      1.158619     -0.462350      1.052256      1.474167
#
#    Value 1p3696  Value 1p4457  Value 1p5217  Value 1p5978  Value 1p6739
# 0     -1.214875     -0.478679     -0.761262      0.347387      2.798564
# 1     -1.061444      0.173883      0.751177     -2.306374      1.345279
# 2     -0.301610      0.941071      0.451451      0.488490      1.727190
# 3      2.362191      1.033810      1.686909      1.734528     -2.808146
# 4      0.012017      2.113732      0.683180      0.962168      1.187910
#
# [5 rows x 24 columns]

# %%
df_freq_noise = pd.read_csv('synthetic_data/FreqNoiseALL-Mean0-Std0to0p2.csv')
df_freq_noise['Timestamp'] = pd.to_datetime(df_freq_noise['Timestamp'])
EDA_freq_noise = MultiEDARunner(df_freq_noise, "Frequency Noise",colormap=plt.cm.Greens)
# Out:
# Columns: Index(['Timestamp', 'Value 0p0', 'Value 0p01', 'Value 0p02', 'Value 0p03',
#        'Value 0p04', 'Value 0p05', 'Value 0p06', 'Value 0p07', 'Value 0p08',
#        'Value 0p09', 'Value 0p1', 'Value 0p11', 'Value 0p12', 'Value 0p13',
#        'Value 0p14', 'Value 0p15', 'Value 0p16', 'Value 0p17', 'Value 0p18',
#        'Value 0p19'],
#       dtype='object')
#             Timestamp  Value 0p0  Value 0p01  Value 0p02  Value 0p03  \
# 0 2020-01-01 00:00:00   0.000000    0.000000    0.000000    0.000000
# 1 2020-01-01 01:00:00   0.062791    0.062781    0.062731    0.062760
# 2 2020-01-01 02:00:00   0.125333    0.125365    0.125289    0.125490
# 3 2020-01-01 03:00:00   0.187381    0.187343    0.187315    0.187245
# 4 2020-01-01 04:00:00   0.248690    0.248743    0.248735    0.248444
#
#    Value 0p04  Value 0p05  Value 0p06  Value 0p07  Value 0p08  ...  Value 0p1  \
# 0    0.000000    0.000000    0.000000    0.000000    0.000000  ...   0.000000
# 1    0.062658    0.062677    0.062595    0.062541    0.062678  ...   0.062742
# 2    0.125509    0.124490    0.125165    0.126296    0.124531  ...   0.124066
# 3    0.186584    0.187682    0.186975    0.187070    0.187024  ...   0.186536
# 4    0.247669    0.247889    0.248460    0.249228    0.248839  ...   0.244267
#
#    Value 0p11  Value 0p12  Value 0p13  Value 0p14  Value 0p15  Value 0p16  \
# 0    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1    0.062940    0.062645    0.063690    0.061824    0.062882    0.062765
# 2    0.126241    0.126247    0.125311    0.126011    0.126541    0.125931
# 3    0.187451    0.187164    0.188333    0.186719    0.185106    0.183417
# 4    0.249076    0.250346    0.245842    0.248694    0.250344    0.250689
#
#    Value 0p17  Value 0p18  Value 0p19
# 0    0.000000    0.000000    0.000000
# 1    0.062815    0.062119    0.062751
# 2    0.123087    0.126698    0.126691
# 3    0.183507    0.187353    0.187731
# 4    0.249974    0.250969    0.252586
#
# [5 rows x 21 columns]

# %%
df_phase_noise = pd.read_csv('synthetic_data/PhaseNoiseALL-Mean0-Std0to1p75.csv')
df_phase_noise['Timestamp'] = pd.to_datetime(df_phase_noise['Timestamp'])
EDA_phase_noise = MultiEDARunner(df_phase_noise, "Phase Noise",colormap=plt.cm.Reds)
# Out:
# Columns: Index(['Timestamp', 'Value 0p0', 'Value 0p0761', 'Value 0p1522',
#        'Value 0p2283', 'Value 0p3043', 'Value 0p3804', 'Value 0p4565',
#        'Value 0p5326', 'Value 0p6087', 'Value 0p6848', 'Value 0p7609',
#        'Value 0p837', 'Value 0p913', 'Value 0p9891', 'Value 1p0652',
#        'Value 1p1413', 'Value 1p2174', 'Value 1p2935', 'Value 1p3696',
#        'Value 1p4457', 'Value 1p5217', 'Value 1p5978', 'Value 1p6739'],
#       dtype='object')
#             Timestamp  Value 0p0  Value 0p0761  Value 0p1522  Value 0p2283  \
# 0 2020-01-01 00:00:00   0.000000      0.038829     -0.019020     -0.363003
# 1 2020-01-01 01:00:00   0.062791     -0.070733      0.192382      0.416641
# 2 2020-01-01 02:00:00   0.125333      0.187496      0.229515     -0.074087
# 3 2020-01-01 03:00:00   0.187381      0.140878      0.135706      0.560354
# 4 2020-01-01 04:00:00   0.248690      0.368632      0.425272     -0.007754
#
#    Value 0p3043  Value 0p3804  Value 0p4565  Value 0p5326  Value 0p6087  ...  \
# 0      0.139520      0.564618      0.688188     -0.097459      0.271065  ...
# 1     -0.099915      0.177948      0.548826      0.400668     -0.677540  ...
# 2     -0.021402     -0.010642      0.740692      0.906004      0.942270  ...
# 3      0.242403     -0.065987     -0.272822      0.624919      0.717014  ...
# 4      0.847524      0.748627      0.296692      0.088339     -0.149067  ...
#
#    Value 0p9891  Value 1p0652  Value 1p1413  Value 1p2174  Value 1p2935  \
# 0      0.491280     -0.371390      0.981219      0.521529     -0.992417
# 1     -0.546517      0.881348     -0.989984     -0.375242     -0.179027
# 2     -0.814220      0.995593      0.998205     -0.905819      0.255545
# 3      0.567975     -0.441584     -0.176268     -0.991948      0.987066
# 4     -0.814229     -0.366760      0.949832     -0.073981      0.738593
#
#    Value 1p3696  Value 1p4457  Value 1p5217  Value 1p5978  Value 1p6739
# 0      0.981010      0.461305      0.163972      0.354408      0.870761
# 1      0.812535      0.103554     -0.745072     -0.931818     -0.557519
# 2     -0.054459     -0.669533      0.968684      0.700366      0.658332
# 3     -0.248009      0.485674     -0.228397     -0.953693     -0.856339
# 4      0.443526      0.994473     -0.991988     -0.547122     -0.945905
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Amplitude Noise
# An overview of the whole data and a zoomed in view. The sine wave becomes less recognizable as the noise increase.

# %%
EDA_amp_noise.overview(columns=df_amp_noise.columns[[1, 2, 10, 20]])
EDA_amp_noise.overview(Zoom_in=(0,1000),columns=df_amp_noise.columns[[1, 2, 10, 20]])
# Out:
# D:\YU\SNP\SNP_project_codes\src\snp\eda.py:387: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Frequency Noise
# An overview of the whole data and a zoomed in view. The noise seem to accumulate as time increase.

# %%
EDA_freq_noise.overview(columns=df_freq_noise.columns[[1, 2, 10, 20]])
EDA_freq_noise.overview(Zoom_in=(0,1000),columns=df_freq_noise.columns[[1, 2, 10, 20]])

# %% [markdown]
# ### Amplitude Noise
# An overview of the whole data and a zoomed in view. The sine wave becomes less recognizable as the noise increase.

# %%
EDA_phase_noise.overview(columns=df_phase_noise.columns[[1, 2, 10, 20]])
EDA_phase_noise.overview(Zoom_in=(0,1000),columns=df_phase_noise.columns[[1, 2, 10, 20]])

# %% [markdown]
# ### variance and standard deviation
# The variance and standard deviation for amplitude noise increase as noise increases. Frequency and phase noise does not change as noise increases.

# %%
EDA_amp_noise.visualize_variance_std_dev()
EDA_freq_noise.visualize_variance_std_dev()
EDA_phase_noise.visualize_variance_std_dev()

# %% [markdown]
# ### Autocorrelation accross datasets

# %%
EDA_amp_noise.pacf_threshold()
EDA_freq_noise.pacf_threshold()
EDA_phase_noise.pacf_threshold()
